# %% [markdown]
# ## Import Libraries and Dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
df=pd.read_csv(r'C:\Users\Mahaveer\Downloads\train_mart.csv')
tdf=pd.read_csv(r'C:\Users\Mahaveer\Downloads\test_mart.csv')

# %%
df.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %%
df.shape
# Out:
# (8523, 12)

# %% [markdown]
# ## Exploratory Data Analysis

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            8523 non-null   object
#  1   Item_Weight                7060 non-null   float64
#  2   Item_Fat_Content           8523 non-null   object
#  3   Item_Visibility            8523 non-null   float64
#  4   Item_Type                  8523 non-null   object
#  5   Item_MRP                   8523 non-null   float64
#  6   Outlet_Identifier          8523 non-null   object
#  7   Outlet_Establishment_Year  8523 non-null   int64
#  8   Outlet_Size                6113 non-null   object
#  9   Outlet_Location_Type       8523 non-null   object
#  10  Outlet_Type                8523 non-null   object
#  11  Item_Outlet_Sales          8523 non-null   float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 799.2+ KB

# %%
df.describe()
# Out:
#        Item_Weight  Item_Visibility     Item_MRP  Outlet_Establishment_Year  \
# count  7060.000000      8523.000000  8523.000000                8523.000000
# mean     12.857645         0.066132   140.992782                1997.831867
# std       4.643456         0.051598    62.275067                   8.371760
# min       4.555000         0.000000    31.290000                1985.000000
# 25%       8.773750         0.026989    93.826500                1987.000000
# 50%      12.600000         0.053931   143.012800                1999.000000
# 75%      16.850000         0.094585   185.643700                2004.000000
# max      21.350000         0.328391   266.888400                2009.000000
#
#        Item_Outlet_Sales
# count        8523.000000
# mean         2181.288914
# std          1706.499616
# min            33.290000
# 25%           834.247400
# 50%          1794.331000
# 75%          3101.296400
# max         13086.964800

# %% [markdown]
# ### Univariate Analysis

# %%
sns.jointplot(x='Item_Weight',y='Item_Outlet_Sales',data=df,kind='reg')

# %%
sns.jointplot(x='Item_Visibility',y='Item_Outlet_Sales',data=df,kind='reg')

# %%
sns.jointplot(x='Item_MRP',y='Item_Outlet_Sales',data=df,kind='reg')

# %%
sns.jointplot(x='Outlet_Establishment_Year',y='Item_Outlet_Sales',data=df,kind='reg')

# %%
sns.distplot(df['Outlet_Establishment_Year'])
# Out:
# <AxesSubplot:xlabel='Outlet_Establishment_Year'>

# %%
sns.distplot(df['Item_Outlet_Sales'])
# Out:
# <AxesSubplot:xlabel='Item_Outlet_Sales'>

# %%
sns.pairplot(df)

# %%
df['Item_Fat_Content']=df.Item_Fat_Content.replace({'low fat':'Low Fat','LF':'Low Fat','reg':'Regular'})

# %%
df.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %% [markdown]
# ### Categorical Variables

# %%
sns.barplot(x='Item_Fat_Content',y='Item_Outlet_Sales',data=df)
# Out:
# <AxesSubplot:xlabel='Item_Fat_Content', ylabel='Item_Outlet_Sales'>

# %%
df.describe(include = ['O'])
# Out:
#        Item_Identifier Item_Fat_Content              Item_Type  \
# count             8523             8523                   8523
# unique            1559                2                     16
# top              FDW13          Low Fat  Fruits and Vegetables
# freq                10             5517                   1232
#
#        Outlet_Identifier Outlet_Size Outlet_Location_Type        Outlet_Type
# count               8523        6113                 8523               8523
# unique                10           3                    3                  4
# top               OUT027      Medium               Tier 3  Supermarket Type1
# freq                 935        2793                 3350               5577

# %%
df[['Item_Fat_Content','Item_Outlet_Sales']].groupby(['Item_Fat_Content'],as_index = False).mean()
# Out:
#   Item_Fat_Content  Item_Outlet_Sales
# 0          Low Fat        2157.711534
# 1          Regular        2224.561170

# %%
df['Item_Outlet_Sales'].mean()
# Out:
# 2181.288913575032

# %%
sns.barplot(y='Item_Type',x='Item_Outlet_Sales',data=df)
# Out:
# <AxesSubplot:xlabel='Item_Outlet_Sales', ylabel='Item_Type'>

# %%
df[['Item_Type','Item_Outlet_Sales']].groupby(['Item_Type'],as_index = False).mean()
# Out:
#                 Item_Type  Item_Outlet_Sales
# 0            Baking Goods        1952.971207
# 1                  Breads        2204.132226
# 2               Breakfast        2111.808651
# 3                  Canned        2225.194904
# 4                   Dairy        2232.542597
# 5            Frozen Foods        2132.867744
# 6   Fruits and Vegetables        2289.009592
# 7             Hard Drinks        2139.221622
# 8      Health and Hygiene        2010.000265
# 9               Household        2258.784300
# 10                   Meat        2158.977911
# 11                 Others        1926.139702
# 12                Seafood        2326.065928
# 13            Snack Foods        2277.321739
# 14            Soft Drinks        2006.511735
# 15          Starchy Foods        2374.332773

# %%
df.head(2)
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility    Item_Type  \
# 0           FDA15         9.30          Low Fat         0.016047        Dairy
# 1           DRC01         5.92          Regular         0.019278  Soft Drinks
#
#    Item_MRP Outlet_Identifier  Outlet_Establishment_Year Outlet_Size  \
# 0  249.8092            OUT049                       1999      Medium
# 1   48.2692            OUT018                       2009      Medium
#
#   Outlet_Location_Type        Outlet_Type  Item_Outlet_Sales
# 0               Tier 1  Supermarket Type1          3735.1380
# 1               Tier 3  Supermarket Type2           443.4228

# %%
df[['Outlet_Size','Item_Outlet_Sales']].groupby(['Outlet_Size'],as_index = False).mean()
# Out:
#   Outlet_Size  Item_Outlet_Sales
# 0        High        2298.995256
# 1      Medium        2681.603542
# 2       Small        1912.149161

# %%
df['Outlet_Establishment_Year'].unique()
# Out:
# array([1999, 2009, 1998, 1987, 1985, 2002, 2007, 1997, 2004], dtype=int64)

# %%
df[['Outlet_Establishment_Year','Item_Outlet_Sales']].groupby(['Outlet_Establishment_Year'],as_index = False).mean()
# Out:
#    Outlet_Establishment_Year  Item_Outlet_Sales
# 0                       1985        2483.677474
# 1                       1987        2298.995256
# 2                       1997        2277.844267
# 3                       1998         339.351662
# 4                       1999        2348.354635
# 5                       2002        2192.384798
# 6                       2004        2438.841866
# 7                       2007        2340.675263
# 8                       2009        1995.498739

# %%
#sns.barplot(y='Outlet_Establishment_Year',x='Item_Outlet_Sales',data=df)

# %%
df[['Outlet_Location_Type','Item_Outlet_Sales']].groupby(['Outlet_Location_Type'],as_index = False).mean()
# Out:
#   Outlet_Location_Type  Item_Outlet_Sales
# 0               Tier 1        1876.909159
# 1               Tier 2        2323.990559
# 2               Tier 3        2279.627651

# %%
sns.barplot(x='Outlet_Location_Type',y='Item_Outlet_Sales',data=df)
# Out:
# <AxesSubplot:xlabel='Outlet_Location_Type', ylabel='Item_Outlet_Sales'>

# %%
df[['Outlet_Type','Item_Outlet_Sales']].groupby(['Outlet_Type'],as_index = False).mean()
# Out:
#          Outlet_Type  Item_Outlet_Sales
# 0      Grocery Store         339.828500
# 1  Supermarket Type1        2316.181148
# 2  Supermarket Type2        1995.498739
# 3  Supermarket Type3        3694.038558

# %%
sns.barplot(x='Outlet_Type',y='Item_Outlet_Sales',data=df)
# Out:
# <AxesSubplot:xlabel='Outlet_Type', ylabel='Item_Outlet_Sales'>

# %%
df.head(2)
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility    Item_Type  \
# 0           FDA15         9.30          Low Fat         0.016047        Dairy
# 1           DRC01         5.92          Regular         0.019278  Soft Drinks
#
#    Item_MRP Outlet_Identifier  Outlet_Establishment_Year Outlet_Size  \
# 0  249.8092            OUT049                       1999      Medium
# 1   48.2692            OUT018                       2009      Medium
#
#   Outlet_Location_Type        Outlet_Type  Item_Outlet_Sales
# 0               Tier 1  Supermarket Type1          3735.1380
# 1               Tier 3  Supermarket Type2           443.4228

# %% [markdown]
# ## Data Wrangling

# %%
df=df.drop(['Item_Identifier','Item_Fat_Content','Item_Type','Outlet_Identifier'],axis=1)

# %%
df.head()
# Out:
#    Item_Weight  Item_Visibility  Item_MRP  Outlet_Establishment_Year  \
# 0         9.30         0.016047  249.8092                       1999
# 1         5.92         0.019278   48.2692                       2009
# 2        17.50         0.016760  141.6180                       1999
# 3        19.20         0.000000  182.0950                       1998
# 4         8.93         0.000000   53.8614                       1987
#
#   Outlet_Size Outlet_Location_Type        Outlet_Type  Item_Outlet_Sales
# 0      Medium               Tier 1  Supermarket Type1          3735.1380
# 1      Medium               Tier 3  Supermarket Type2           443.4228
# 2      Medium               Tier 1  Supermarket Type1          2097.2700
# 3         NaN               Tier 3      Grocery Store           732.3800
# 4        High               Tier 3  Supermarket Type1           994.7052

# %%
#data=pd.get_dummies(df)

# %%
#data.columns

# %%
df.head()
# Out:
#    Item_Weight  Item_Visibility  Item_MRP  Outlet_Establishment_Year  \
# 0         9.30         0.016047  249.8092                       1999
# 1         5.92         0.019278   48.2692                       2009
# 2        17.50         0.016760  141.6180                       1999
# 3        19.20         0.000000  182.0950                       1998
# 4         8.93         0.000000   53.8614                       1987
#
#   Outlet_Size Outlet_Location_Type        Outlet_Type  Item_Outlet_Sales
# 0      Medium               Tier 1  Supermarket Type1          3735.1380
# 1      Medium               Tier 3  Supermarket Type2           443.4228
# 2      Medium               Tier 1  Supermarket Type1          2097.2700
# 3         NaN               Tier 3      Grocery Store           732.3800
# 4        High               Tier 3  Supermarket Type1           994.7052

# %%
df.isnull().sum()
# Out:
# Item_Weight                  1463
# Item_Visibility                 0
# Item_MRP                        0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
df['Item_Weight']=df.Item_Weight.fillna(df['Item_Weight'].mean())

# %%
df.Outlet_Size.unique()
# Out:
# array(['Medium', nan, 'High', 'Small'], dtype=object)

# %%
df['Outlet_Size']=df.Outlet_Size.fillna(df['Outlet_Size'].mode()[0])

# %%
df.Outlet_Size.unique()
# Out:
# array(['Medium', 'High', 'Small'], dtype=object)

# %%
df.head()
# Out:
#    Item_Weight  Item_Visibility  Item_MRP  Outlet_Establishment_Year  \
# 0         9.30         0.016047  249.8092                       1999
# 1         5.92         0.019278   48.2692                       2009
# 2        17.50         0.016760  141.6180                       1999
# 3        19.20         0.000000  182.0950                       1998
# 4         8.93         0.000000   53.8614                       1987
#
#   Outlet_Size Outlet_Location_Type        Outlet_Type  Item_Outlet_Sales
# 0      Medium               Tier 1  Supermarket Type1          3735.1380
# 1      Medium               Tier 3  Supermarket Type2           443.4228
# 2      Medium               Tier 1  Supermarket Type1          2097.2700
# 3      Medium               Tier 3      Grocery Store           732.3800
# 4        High               Tier 3  Supermarket Type1           994.7052

# %%
df.to_csv('Bigmart.csv')

# %%
data=pd.get_dummies(df)

# %%
data.columns
# Out:
# Index(['Item_Weight', 'Item_Visibility', 'Item_MRP',
#        'Outlet_Establishment_Year', 'Item_Outlet_Sales', 'Outlet_Size_High',
#        'Outlet_Size_Medium', 'Outlet_Size_Small',
#        'Outlet_Location_Type_Tier 1', 'Outlet_Location_Type_Tier 2',
#        'Outlet_Location_Type_Tier 3', 'Outlet_Type_Grocery Store',
#        'Outlet_Type_Supermarket Type1', 'Outlet_Type_Supermarket Type2',
#        'Outlet_Type_Supermarket Type3'],
#       dtype='object')

# %%
a=data.drop(['Outlet_Size_High','Outlet_Location_Type_Tier 1','Outlet_Type_Grocery Store'],axis=1)

# %%
a.head()
# Out:
#    Item_Weight  Item_Visibility  Item_MRP  Outlet_Establishment_Year  \
# 0         9.30         0.016047  249.8092                       1999
# 1         5.92         0.019278   48.2692                       2009
# 2        17.50         0.016760  141.6180                       1999
# 3        19.20         0.000000  182.0950                       1998
# 4         8.93         0.000000   53.8614                       1987
#
#    Item_Outlet_Sales  Outlet_Size_Medium  Outlet_Size_Small  \
# 0          3735.1380                   1                  0
# 1           443.4228                   1                  0
# 2          2097.2700                   1                  0
# 3           732.3800                   1                  0
# 4           994.7052                   0                  0
#
#    Outlet_Location_Type_Tier 2  Outlet_Location_Type_Tier 3  \
# 0                            0                            0
# 1                            0                            1
# ...

# %%
X = a.drop('Item_Outlet_Sales',1)
y = a.Item_Outlet_Sales

# %%
df=pd.read_csv(r'C:\Users\Mahaveer\Downloads\train_mart.csv')
tdf=pd.read_csv(r'C:\Users\Mahaveer\Downloads\test_mart.csv')

# %%
df['Item_Fat_Content']=df.Item_Fat_Content.replace({'low fat':'Low Fat','LF':'Low Fat','reg':'Regular'})

df=df.drop(['Item_Identifier','Item_Fat_Content','Item_Type','Outlet_Identifier','Outlet_Location_Type'],axis=1)
df['Item_Weight']=df.Item_Weight.fillna(df['Item_Weight'].mean())
df['Outlet_Size']=df.Outlet_Size.fillna(df['Outlet_Size'].mode()[0])
df['Outlet_Size'] = df['Outlet_Size'].map({'High':3,'Medium':2,'Low':1})
data=pd.get_dummies(df)
#data=data1.drop('Outlet_Type_Grocery Store',1)
data['Outlet_Size']=data.Outlet_Size.fillna(data['Outlet_Size'].mode()[0])
m=tdf['Item_Identifier'].values
n=tdf['Outlet_Identifier'].values

# %%
tdf['Item_Fat_Content']=tdf.Item_Fat_Content.replace({'low fat':'Low Fat','LF':'Low Fat','reg':'Regular'})
tdf=tdf.drop(['Item_Identifier','Item_Fat_Content','Item_Type','Outlet_Identifier','Outlet_Location_Type'],axis=1)
tdf['Item_Weight']=tdf.Item_Weight.fillna(df['Item_Weight'].mean())
tdf['Outlet_Size']=tdf.Outlet_Size.fillna(df['Outlet_Size'].mode()[0])
tdf['Outlet_Size'] = tdf['Outlet_Size'].map({'High':3,'Medium':2,'Low':1})

# %%
data2=pd.get_dummies(tdf)
test=data2

# %%
test['Outlet_Size']=test.Outlet_Size.fillna(test['Outlet_Size'].mode()[0])

# %%
test.loc[test['Item_Visibility']==0,['Item_Visibility']]=test.Item_Visibility.mean()

# %% [markdown]
# ## Training Model Using Scikit-Learn

# %%
X_train=data.drop('Item_Outlet_Sales',1)
X_test= test
y_train=data.Item_Outlet_Sales

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
scaler=StandardScaler()

# %%
X_train_scaled=scaler.fit_transform(X_train)
X_test_scaled=scaler.transform(X_test)

# %%
from sklearn.linear_model import LinearRegression

# %%
rg=LinearRegression().fit(X_train_scaled,y_train)

# %%
rg_pred=rg.predict(X_test_scaled)

# %%
submit=pd.DataFrame({'Item_Identifier':m,'Outlet_Identifier':n,'Item_Outlet_Sales':rg_pred})

# %%
submit
# Out:
#      Item_Identifier Outlet_Identifier  Item_Outlet_Sales
# 0              FDW58            OUT049        1797.616535
# 1              FDW14            OUT017        1513.287456
# 2              NCN55            OUT010        1947.594835
# 3              FDQ58            OUT017        2573.602549
# 4              FDY38            OUT027        5148.303598
# ...              ...               ...                ...
# 5676           FDB58            OUT046        2313.856453
# 5677           FDD47            OUT018        2405.139109
# 5678           NCO17            OUT045        1969.947983
# 5679           FDJ26            OUT017        3483.377022
# 5680           FDU37            OUT045        1356.122387
#
# [5681 rows x 3 columns]

# %%
submit.loc[submit['Item_Outlet_Sales']<0,['Item_Outlet_Sales']]=0
